# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))
sys.path.insert(0, os.path.abspath('..\\scripts'))
from helpers import get_models_dir, get_processed_data_dir, make_data_loader, resnet_learner

# %%
processed_data_dir = get_processed_data_dir()
for label in os.listdir(processed_data_dir):    
    dir_path = os.path.join(processed_data_dir, label)
    print(dir_path)    
    for image_path in os.listdir(dir_path):        
        print(image_path)
# Out:
# D:\ENGINEERING\mezcal\data\processed\background
# background-cuishe_20210415145307.jpg
# background-cuishe_20210415145715.jpg
# background-ESPAD+N 10X RING  2.jpg
# background-ESPAD+N 4X C  1.jpg
# background-ESPADIN 1 10X RING  2.jpg
# background-ESPADIN 10 10X RING B 2.jpg
# background-ESPADIN 10 4X B 1.jpg
# background-ESPADIN 10 4X B 2.jpg
# background-ESPADIN 10 4X CENTRO  2.jpg
# background-ESPADIN 5 10X MEDIO   2.jpg
# background-ESPADIN 5 10X RING   2.jpg
# background-ESPADIN 5 4X   1.jpg
# background-ESPADIN 6 4X    2.jpg
# background-ESPADIN 8 10X MEDIO 1.jpg
# background-espadin_20210415142409.jpg
# background-espadin_20210415142416.jpg
# background-espadin_20210415142522.jpg
# background-espadin_20210415150750.jpg
# background-M1ESPADIN4X1.jpg
# background-objetivo 10 x centro 2da muestra.jpg
# background-objetivo 4x anillo (3).jpg
# background-PECHUGA 10X CENTRO B  2.jpg
# background-PECHUGA 4X D  1.jpg
# background-pechuga.jpg
# background-pechuga_20210415143453.jpg
# ...
